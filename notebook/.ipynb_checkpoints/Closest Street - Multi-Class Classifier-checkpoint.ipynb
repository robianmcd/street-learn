# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import random
from ipyleaflet import Map, Circle
import seaborn as sns
sns.set()
from IPython.display import display
# Out:
# Using TensorFlow backend.

# %%
def min_max_normalize(series):
    return (series - series.min()) / (series.max()-series.min())

cmap = plt.get_cmap('jet')
colors = [matplotlib.colors.rgb2hex(rgb) for rgb in cmap(np.linspace(0, 1, 28))]
random.shuffle(colors)

def addPoint(map, lat, lng, street_name, predicted_street_name=None):
    color_index = list(raw_df.streetName.unique()).index(street_name)
    if not (predicted_street_name is None) and predicted_street_name != street_name:
        color = '#000'
    else:
        color = colors[color_index]
        
    map.add_layer(Circle(location=[lat, lng], radius=4, color=color, opacity=.3, fill_opacity=.3, fill_color=color))

# %% [markdown]
# # Prepare the Data

# %%
raw_df = pd.read_csv('closest-street.csv')
#shuffel the places
raw_df = raw_df.sample(frac=1).reset_index(drop=True)

df = raw_df;

df = pd.get_dummies(df, columns=['streetName'])
df.lat = min_max_normalize(df.lat)
df.lng = min_max_normalize(df.lng)

inputMatrix = df[['lat', 'lng']].as_matrix()
street_name_cols = [col for col in list(df) if col.startswith('streetName')]
target = df[street_name_cols].as_matrix()

df.describe()
# Out:
#                lat          lng  streetName_Adelaide Pl  \
# count  6132.000000  6132.000000             6132.000000
# mean      0.502263     0.501506                0.012394
# std       0.293978     0.287435                0.110645
# min       0.000000     0.000000                0.000000
# 25%       0.247877     0.253573                0.000000
# 50%       0.503656     0.498858                0.000000
# 75%       0.760177     0.751681                0.000000
# max       1.000000     1.000000                1.000000
#
#        streetName_Adelaide St W  streetName_Bathurst St  \
# count               6132.000000             6132.000000
# mean                   0.109589                0.017449
# std                    0.312402                0.130949
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                0.000000
# 75%                    0.000000                0.000000
# max                    1.000000                1.000000
#
#        streetName_Blue Jays Way  streetName_Brant Pl  streetName_Brant St  \
# count               6132.000000          6132.000000          6132.000000
# mean                   0.042401             0.009295             0.040933
# std                    0.201518             0.095972             0.198151
# min                    0.000000             0.000000             0.000000
# 25%                    0.000000             0.000000             0.000000
# 50%                    0.000000             0.000000             0.000000
# 75%                    0.000000             0.000000             0.000000
# max                    1.000000             1.000000             1.000000
#
#        streetName_Browns Ln  streetName_Camden St          ...            \
# count           6132.000000           6132.000000          ...
# mean               0.002120              0.000978          ...
# std                0.045999              0.031268          ...
# min                0.000000              0.000000          ...
# 25%                0.000000              0.000000          ...
# 50%                0.000000              0.000000          ...
# 75%                0.000000              0.000000          ...
# max                1.000000              1.000000          ...
#
#        streetName_Oxley St  streetName_Peter St  streetName_Portland St  \
# count          6132.000000          6132.000000             6132.000000
# mean              0.013372             0.008480                0.059198
# std               0.114873             0.091704                0.236014
# min               0.000000             0.000000                0.000000
# 25%               0.000000             0.000000                0.000000
# 50%               0.000000             0.000000                0.000000
# 75%               0.000000             0.000000                0.000000
# max               1.000000             1.000000                1.000000
#
#        streetName_Richmond St W  streetName_Spadina Ave  \
# count               6132.000000             6132.000000
# mean                   0.024788                0.078278
# std                    0.155491                0.268630
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                0.000000
# 75%                    0.000000                0.000000
# max                    1.000000                1.000000
#
#        streetName_Stewart St  streetName_Waterloo Terrace  \
# count            6132.000000                  6132.000000
# mean                0.013862                     0.007665
# std                 0.116926                     0.087219
# min                 0.000000                     0.000000
# 25%                 0.000000                     0.000000
# 50%                 0.000000                     0.000000
# 75%                 0.000000                     0.000000
# max                 1.000000                     1.000000
#
#        streetName_Wellington St W  streetName_Widmer St  streetName_Windsor St
# count                 6132.000000           6132.000000            6132.000000
# mean                     0.125082              0.002772               0.012394
# std                      0.330838              0.052584               0.110645
# min                      0.000000              0.000000               0.000000
# 25%                      0.000000              0.000000               0.000000
# 50%                      0.000000              0.000000               0.000000
# 75%                      0.000000              0.000000               0.000000
# max                      1.000000              1.000000               1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# # Visualize the Data

# %%
map = Map(center=[raw_df.lat.mean(), raw_df.lng.mean()], zoom=17)

for index, row in raw_df.iterrows():
    addPoint(map, lat=row.lat, lng=row.lng, street_name=row.streetName)

map
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-28ecc086a557> in <module>()
#       2
#       3 for index, row in raw_df.iterrows():
# ----> 4     addPoint(map, lat=row.lat, lng=row.lng, street_name=row.streetName)
#       5
#       6 map
#
# <ipython-input-2-4014763efb2e> in addPoint(map, lat, lng, street_name, predicted_street_name)
#      13         color = colors[color_index]
#      14
# ---> 15     map.add_layer(Circle(location=[lat, lng], radius=4, color=color, opacity=.3, fill_opacity=.3, fill_color=color))
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipyleaflet\leaflet.py in add_layer(self, layer)
#     451             raise LayerException('layer already on map: %r' % layer)
#     452         layer._map = self
# --> 453         self.layers = tuple([l for l in self.layers] + [layer])
#     454         layer.visible = True
#     455
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\traitlets\traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     395             if name in self.keys and self._should_send_property(name, change['new']):
#     396                 # Send new state to front-end
# --> 397                 self.send_state(key=name)
#     398         LoggingConfigurable.notify_change(self, change)
#     399
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipywidgets\widgets\widget.py in send_state(self, key)
#     280         state, buffer_keys, buffers = self._split_state_buffers(state)
#     281         msg = {'method': 'update', 'state': state, 'buffers': buffer_keys}
# --> 282         self._send(msg, buffers=buffers)
#     283
#     284     def get_state(self, key=None, drop_defaults=False):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipywidgets\widgets\widget.py in _send(self, msg, buffers)
#     534         """Sends a message to the model in the front-end."""
#     535         if self.comm is not None and self.comm.kernel is not None:
# --> 536             self.comm.send(data=msg, buffers=buffers)
#     537
#     538
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\comm\comm.py in send(self, data, metadata, buffers)
#     119         """Send a message to the frontend-side version of this comm"""
#     120         self._publish_msg('comm_msg',
# --> 121             data=data, metadata=metadata, buffers=buffers,
#     122         )
#     123
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\comm\comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      63         data = {} if data is None else data
#      64         metadata = {} if metadata is None else metadata
# ---> 65         content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
#      66         self.kernel.session.send(self.kernel.iopub_socket, msg_type,
#      67             content,
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     165         out = {}
#     166         for k,v in iteritems(obj):
# --> 167             out[unicode_type(k)] = json_clean(v)
#     168         return out
#     169     if isinstance(obj, datetime):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     165         out = {}
#     166         for k,v in iteritems(obj):
# --> 167             out[unicode_type(k)] = json_clean(v)
#     168         return out
#     169     if isinstance(obj, datetime):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     165         out = {}
#     166         for k,v in iteritems(obj):
# --> 167             out[unicode_type(k)] = json_clean(v)
#     168         return out
#     169     if isinstance(obj, datetime):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     151
#     152     if isinstance(obj, list):
# --> 153         return [json_clean(x) for x in obj]
#     154
#     155     if isinstance(obj, dict):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in <listcomp>(.0)
#     151
#     152     if isinstance(obj, list):
# --> 153         return [json_clean(x) for x in obj]
#     154
#     155     if isinstance(obj, dict):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     134         return int(obj)
#     135
# --> 136     if isinstance(obj, numbers.Real):
#     137         # cast out-of-range floats to their reprs
#     138         if math.isnan(obj) or math.isinf(obj):
#
# c:\users\robia\appdata\local\programs\python\python35\lib\abc.py in __instancecheck__(cls, instance)
#     179         """Override for isinstance(instance, cls)."""
#     180         # Inline the cache checking
# --> 181         subclass = instance.__class__
#     182         if subclass in cls._abc_cache:
#     183             return True
#
# KeyboardInterrupt:

# %%
chart = sns.lmplot('lat', 'lng', data=raw_df, hue='streetName', col='streetName', fit_reg=False)
chart.set(xlim=(raw_df['lat'].min(), raw_df['lat'].max()))
chart.set(ylim=(raw_df['lng'].min(), raw_df['lng'].max()))
plt.show()

# %% [markdown]
# # Train the Model

# %%
def get_model():
    model = Sequential()
    model.add(Dense(60, input_dim=2, activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(60, activation='relu'))
    model.add(Dense(28, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
model = get_model()

training_data = model.fit(inputMatrix, target, validation_split=0.3, epochs=100, batch_size=10, verbose=False)

fig, axis = plt.subplots(1,2)
fig.set_size_inches(14, 4.5)
axis[0].plot(training_data.history['val_loss'], 'g', training_data.history['loss'], 'r')
axis[0].set_xlabel('Epochs')
axis[0].set_ylabel('Loss')
axis[1].plot(training_data.history['val_acc'], 'g', training_data.history['acc'], 'r')
axis[1].set_xlabel('Epochs')
axis[1].set_ylabel('Accuracy')
plt.show()

print('Accuracy: %.2f%%' % (training_data.history['val_acc'][-1]*100))
# Out:
# Accuracy: 84.02%

# %% [markdown]
# # Visualize the Model

# %%
input_index = 0;

predicted_match = model.predict(np.array([inputMatrix[input_index]]));

street_names = [name.replace('streetName_', '') for name in street_name_cols]

plt.bar(range(28), predicted_match[0])
plt.xticks(range(28), street_names, rotation='vertical')
#plt.yscale('log')
plt.show()

print(raw_df.iloc[[input_index]])
# Out:
#          lat        lng     streetName
# 0  43.646142 -79.398289  Adelaide St W

# %%
increment = round(len(inputMatrix)/10)

x = []
y = []
yStd = []

for i in range(10):
    numSamples = (i+1) * increment
    
    estimator = KerasClassifier(build_fn=get_model, epochs=100, batch_size=10, verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True)
    results = cross_val_score(estimator, inputMatrix, target, cv=kfold)
    print('Accuracy: %.2f%% (%.2f%%)' % (results.mean()*100, results.std()*100))
    
    x.append(numSamples)
    y.append(results.mean())
    yStd.append(results.std())

plt.errorbar(x, y, yerr=yStd)
plt.show()

# %%
map = Map(center=[raw_df.lat.mean(), raw_df.lng.mean()], zoom=17)

for index, input_row in enumerate(inputMatrix):
    predicted_match_scores = list(model.predict(np.array([input_row]))[0])
    predicted_street_index = predicted_match_scores.index(max(predicted_match_scores))
    predicted_street_name = street_names[predicted_street_index]
    
    raw_row = raw_df.loc[index]
    addPoint(map, lat=raw_row.lat, lng=raw_row.lng, street_name=raw_row.streetName, predicted_street_name=predicted_street_name)

map
